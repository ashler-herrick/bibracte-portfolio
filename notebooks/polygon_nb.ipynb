# %%
import os
import boto3
import gzip
import shutil
import polars as pl
from botocore.config import Config
from bet_edge.data_io.env_cred_provider import EnvCredProvider

# Initialize a session using your credentials
ecp = EnvCredProvider()
creds = ecp.get_credentials()

session = boto3.Session(
   aws_access_key_id=creds['polygon_access_key_id'],
   aws_secret_access_key=creds['polygon_secret_access_key'],
)

# Create an S3 client
s3 = session.client(
   's3',
   endpoint_url='https://files.polygon.io',
   config=Config(signature_version='s3v4'),
)

# Set bucket name and prefix
bucket_name = 'flatfiles'
prefix = 'us_options_opra/day_aggs_v1'  # Only process 'day_aggs_v1' data

# Define local storage path
base_local_dir = os.path.join('..', '..', 'data_lake')

# Initialize paginator for listing S3 objects
paginator = s3.get_paginator('list_objects_v2')

# Process files
for page in paginator.paginate(Bucket=bucket_name, Prefix=prefix):
    for obj in page.get('Contents', []):
        object_key = obj['Key']

        # Skip files that are not .csv.gz
        if not object_key.endswith('.csv.gz'):
            continue

        try:
            # Construct full local file path preserving folder structure
            local_file_path = os.path.join(base_local_dir, *object_key.split('/'))
            decompressed_file_path = local_file_path.replace('.gz', '')
            parquet_file_path = decompressed_file_path.replace('.csv', '.parquet')

            # Ensure directory structure exists
            os.makedirs(os.path.dirname(local_file_path), exist_ok=True)

            # Download file from S3
            print(f"Downloading: {object_key}")
            s3.download_file(bucket_name, object_key, local_file_path)

            # Decompress the file
            print(f"Decompressing: {local_file_path}")
            with gzip.open(local_file_path, 'rb') as f_in:
                with open(decompressed_file_path, 'wb') as f_out:
                    shutil.copyfileobj(f_in, f_out)

            # Convert CSV to Parquet
            print(f"Converting to Parquet: {parquet_file_path}")
            df = pl.read_csv(decompressed_file_path)
            df.write_parquet(parquet_file_path)

            # Clean up - remove original compressed and decompressed CSV
            os.remove(local_file_path)
            os.remove(decompressed_file_path)

            print(f"Stored as Parquet: {parquet_file_path}\n")

        except Exception as e:
            print(f"Error processing {object_key}: {e}")
# Out:
# Downloading: us_options_opra/day_aggs_v1/2014/06/2014-06-02.csv.gz
# Error processing us_options_opra/day_aggs_v1/2014/06/2014-06-02.csv.gz: An error occurred (403) when calling the HeadObject operation: Forbidden
# Downloading: us_options_opra/day_aggs_v1/2014/06/2014-06-03.csv.gz
# Error processing us_options_opra/day_aggs_v1/2014/06/2014-06-03.csv.gz: An error occurred (403) when calling the HeadObject operation: Forbidden
# Downloading: us_options_opra/day_aggs_v1/2014/06/2014-06-04.csv.gz
# Error processing us_options_opra/day_aggs_v1/2014/06/2014-06-04.csv.gz: An error occurred (403) when calling the HeadObject operation: Forbidden
# Downloading: us_options_opra/day_aggs_v1/2014/06/2014-06-05.csv.gz
# Error processing us_options_opra/day_aggs_v1/2014/06/2014-06-05.csv.gz: An error occurred (403) when calling the HeadObject operation: Forbidden
# Downloading: us_options_opra/day_aggs_v1/2014/06/2014-06-06.csv.gz
# Error processing us_options_opra/day_aggs_v1/2014/06/2014-06-06.csv.gz: An error occurred (403) when calling the HeadObject operation: Forbidden
# Downloading: us_options_opra/day_aggs_v1/2014/06/2014-06-09.csv.gz
# Error processing us_options_opra/day_aggs_v1/2014/06/2014-06-09.csv.gz: An error occurred (403) when calling the HeadObject operation: Forbidden
# Downloading: us_options_opra/day_aggs_v1/2014/06/2014-06-10.csv.gz
# Error processing us_options_opra/day_aggs_v1/2014/06/2014-06-10.csv.gz: An error occurred (403) when calling the HeadObject operation: Forbidden
# Downloading: us_options_opra/day_aggs_v1/2014/06/2014-06-11.csv.gz
# Error processing us_options_opra/day_aggs_v1/2014/06/2014-06-11.csv.gz: An error occurred (403) when calling the HeadObject operation: Forbidden
# Downloading: us_options_opra/day_aggs_v1/2014/06/2014-06-12.csv.gz
# Error processing us_options_opra/day_aggs_v1/2014/06/2014-06-12.csv.gz: An error occurred (403) when calling the HeadObject operation: Forbidden
# Downloading: us_options_opra/day_aggs_v1/2014/06/2014-06-13.csv.gz
# Error processing us_options_opra/day_aggs_v1/2014/06/2014-06-13.csv.gz: An error occurred (403) when calling the HeadObject operation: Forbidden
# Downloading: us_options_opra/day_aggs_v1/2014/06/2014-06-16.csv.gz
# Error processing us_options_opra/day_aggs_v1/2014/06/2014-06-16.csv.gz: An error occurred (403) when calling the HeadObject operation: Forbidden
# Downloading: us_options_opra/day_aggs_v1/2014/06/2014-06-17.csv.gz
# Error processing us_options_opra/day_aggs_v1/2014/06/2014-06-17.csv.gz: An error occurred (403) when calling the HeadObject operation: Forbidden
# Downloading: us_options_opra/day_aggs_v1/2014/06/2014-06-18.csv.gz
# Error processing us_options_opra/day_aggs_v1/2014/06/2014-06-18.csv.gz: An error occurred (403) when calling the HeadObject operation: Forbidden
# Downloading: us_options_opra/day_aggs_v1/2014/06/2014-06-19.csv.gz
# Error processing us_options_opra/day_aggs_v1/2014/06/2014-06-19.csv.gz: An error occurred (403) when calling the HeadObject operation: Forbidden
# Downloading: us_options_opra/day_aggs_v1/2014/06/2014-06-20.csv.gz
# Error processing us_options_opra/day_aggs_v1/2014/06/2014-06-20.csv.gz: An error occurred (403) when calling the HeadObject operation: Forbidden
# Downloading: us_options_opra/day_aggs_v1/2014/06/2014-06-23.csv.gz
# Error processing us_options_opra/day_aggs_v1/2014/06/2014-06-23.csv.gz: An error occurred (403) when calling the HeadObject operation: Forbidden
# Downloading: us_options_opra/day_aggs_v1/2014/06/2014-06-24.csv.gz
# Error processing us_options_opra/day_aggs_v1/2014/06/2014-06-24.csv.gz: An error occurred (403) when calling the HeadObject operation: Forbidden
# Downloading: us_options_opra/day_aggs_v1/2014/06/2014-06-25.csv.gz
# Error processing us_options_opra/day_aggs_v1/2014/06/2014-06-25.csv.gz: An error occurred (403) when calling the HeadObject operation: Forbidden
# Downloading: us_options_opra/day_aggs_v1/2014/06/2014-06-26.csv.gz
# Error processing us_options_opra/day_aggs_v1/2014/06/2014-06-26.csv.gz: An error occurred (403) when calling the HeadObject operation: Forbidden
# Downloading: us_options_opra/day_aggs_v1/2014/06/2014-06-27.csv.gz
# Error processing us_options_opra/day_aggs_v1/2014/06/2014-06-27.csv.gz: An error occurred (403) when calling the HeadObject operation: Forbidden
# Downloading: us_options_opra/day_aggs_v1/2014/06/2014-06-30.csv.gz
# Error processing us_options_opra/day_aggs_v1/2014/06/2014-06-30.csv.gz: An error occurred (403) when calling the HeadObject operation: Forbidden
# Downloading: us_options_opra/day_aggs_v1/2014/07/2014-07-01.csv.gz
# Error processing us_options_opra/day_aggs_v1/2014/07/2014-07-01.csv.gz: An error occurred (403) when calling the HeadObject operation: Forbidden
# Downloading: us_options_opra/day_aggs_v1/2014/07/2014-07-02.csv.gz
# Error processing us_options_opra/day_aggs_v1/2014/07/2014-07-02.csv.gz: An error occurred (403) when calling the HeadObject operation: Forbidden
# Downloading: us_options_opra/day_aggs_v1/2014/07/2014-07-03.csv.gz
# Error processing us_options_opra/day_aggs_v1/2014/07/2014-07-03.csv.gz: An error occurred (403) when calling the HeadObject operation: Forbidden
# Downloading: us_options_opra/day_aggs_v1/2014
# │ O:A230421C00155000 ┆ 347    ┆ 0.05 ┆ 0.05  ┆ 0.05 ┆ 0.04 ┆ 1681099200000000000 ┆ 37           │
# │ O:A230421P00125000 ┆ 2      ┆ 0.3  ┆ 0.28  ┆ 0.3  ┆ 0.28 ┆ 1681099200000000000 ┆ 2            │
# │ O:A230421P00130000 ┆ 10     ┆ 0.75 ┆ 0.51  ┆ 0.8  ┆ 0.51 ┆ 1681099200000000000 ┆ 6            │
# └────────────────────┴────────┴──────┴───────┴──────┴──────┴─────────────────────┴──────────────┘
# Schema([('ticker', String), ('volume', Int64), ('open', Float64), ('close', Float64), ('high', Float64), ('low', Float64), ('window_start', Int64), ('transactions', Int64)])

# %%
df
# Out:
# shape: (176_852, 8)
# ┌───────────────────────┬────────┬──────┬───────┬──────┬──────┬─────────────────────┬──────────────┐
# │ ticker                ┆ volume ┆ open ┆ close ┆ high ┆ low  ┆ window_start        ┆ transactions │
# │ ---                   ┆ ---    ┆ ---  ┆ ---   ┆ ---  ┆ ---  ┆ ---                 ┆ ---          │
# │ str                   ┆ i64    ┆ f64  ┆ f64   ┆ f64  ┆ f64  ┆ i64                 ┆ i64          │
# ╞═══════════════════════╪════════╪══════╪═══════╪══════╪══════╪═════════════════════╪══════════════╡
# │ O:A230421C00140000    ┆ 3      ┆ 1.15 ┆ 1.41  ┆ 1.41 ┆ 1.15 ┆ 1681099200000000000 ┆ 3            │
# │ O:A230421C00145000    ┆ 1      ┆ 0.25 ┆ 0.25  ┆ 0.25 ┆ 0.25 ┆ 1681099200000000000 ┆ 1            │
# │ O:A230421C00155000    ┆ 347    ┆ 0.05 ┆ 0.05  ┆ 0.05 ┆ 0.04 ┆ 1681099200000000000 ┆ 37           │
# │ O:A230421P00125000    ┆ 2      ┆ 0.3  ┆ 0.28  ┆ 0.3  ┆ 0.28 ┆ 1681099200000000000 ┆ 2            │
# │ O:A230421P00130000    ┆ 10     ┆ 0.75 ┆ 0.51  ┆ 0.8  ┆ 0.51 ┆ 1681099200000000000 ┆ 6            │
# │ …                     ┆ …      ┆ …    ┆ …     ┆ …    ┆ …    ┆ …                   ┆ …            │
# │ O:ZYME231020P00010000 ┆ 5      ┆ 2.0  ┆ 2.0   ┆ 2.0  ┆ 2.0  ┆ 1681099200000000000 ┆ 1            │
# │ O:ZYXI230421P00010000 ┆ 5      ┆ 0.1  ┆ 0.1   ┆ 0.1  ┆ 0.1  ┆ 1681099200000000000 ┆ 1            │
# │ O:ZYXI230519C00012500 ┆ 3      ┆ 0.95 ┆ 0.6   ┆ 0.95 ┆ 0.6  ┆ 1681099200000000000 ┆ 2            │
# │ O:ZYXI230519C00015000 ┆ 1      ┆ 0.2  ┆ 0.2   ┆ 0.2  ┆ 0.2  ┆ 1681099200000000000 ┆ 1            │
# │ O:ZYXI230519C00020000 ┆ 7      ┆ 0.05 ┆ 0.05  ┆ 0.05 ┆ 0.05 ┆ 1681099200000000000 ┆ 2            │
# └───────────────────────┴────────┴──────┴───────┴──────┴──────┴─────────────────────┴──────────────┘
